# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
omega = 0.1053786838
lih_pes = np.loadtxt("LiH_PBE.txt")

# %%
plt.plot(lih_pes[:,0], lih_pes[:,1]+omega, label="S0 Uncoupled")
plt.plot(lih_pes[:,0], lih_pes[:,2], label="S1 Uncoupled")
plt.plot(lih_pes[:,0], lih_pes[:,3], label="S0+w lambda = 0")
plt.plot(lih_pes[:,0], lih_pes[:,4], label="S0+w lambda = 0")
plt.plot(lih_pes[:,0], lih_pes[:,5], label="LP 0.01")
plt.plot(lih_pes[:,0], lih_pes[:,6], label="UP 0.01")
plt.plot(lih_pes[:,0], lih_pes[:,7], label="LP 0.05")
plt.plot(lih_pes[:,0], lih_pes[:,8], label="UP 0.05")
plt.plot(lih_pes[:,0], lih_pes[:,9], label="LP 0.1")
plt.plot(lih_pes[:,0], lih_pes[:,10], label="UP 0.1")
#plt.xlim(0.4, 1.0)
plt.ylim(-8.1, -7.75)
plt.legend()
plt.show()
