# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
omega = 0.4739
h2_pes = np.loadtxt("H2_PBE.txt")

# %%
plt.plot(h2_pes[:,0], h2_pes[:,1]+omega, label="S0 Uncoupled")
plt.plot(h2_pes[:,0], h2_pes[:,2], label="S1 Uncoupled")
plt.plot(h2_pes[:,0], h2_pes[:,3], label="S0 lambda = 0")
plt.plot(h2_pes[:,0], h2_pes[:,4], label="LP 0.01")
plt.plot(h2_pes[:,0], h2_pes[:,5], label="UP 0.01")
#plt.plot(h2_pes[:,0], h2_pes[:,6], label="LP 0.02")
#plt.plot(h2_pes[:,0], h2_pes[:,7], label="UP 0.02")
#plt.plot(h2_pes[:,0], h2_pes[:,8], label="LP 0.03")
#plt.plot(h2_pes[:,0], h2_pes[:,9], label="UP 0.03")
#plt.plot(h2_pes[:,0], h2_pes[:,10], label="LP 0.04")
#plt.plot(h2_pes[:,0], h2_pes[:,11], label="UP 0.04")
plt.plot(h2_pes[:,0], h2_pes[:,12], label="LP 0.05")
plt.plot(h2_pes[:,0], h2_pes[:,13], label="UP 0.05")
plt.plot(h2_pes[:,0], h2_pes[:,14], label="LP 0.1")
plt.plot(h2_pes[:,0], h2_pes[:,15], label="UP 0.1")
#plt.xlim(0.4, 1.0)
#plt.ylim(-0.8, -0.5)
plt.legend()
plt.show()
