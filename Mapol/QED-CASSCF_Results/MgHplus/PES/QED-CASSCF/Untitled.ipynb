# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
pes = np.load('mghplus_casscf_8e_12o_ccpVDZ_no_cavity.npy')
pes_lz_0p01 = np.load('mghplus_casscf_8e_12o_10ph_ccpVDZ_lambda_0.01_om_0.136.npy')
pes_lz_0p05 = np.load('mghplus_casscf_8e_12o_10ph_ccpVDZ_lambda_0.05_om_0.136.npy')

# %%
plt.plot(pes[0,:], pes[1,:], 'black', label='S0 uncoupled')
plt.plot(pes_lz_0p01[0,:], pes_lz_0p01[1,:], 'r--', label='S0 lz = 0.01')
plt.plot(pes_lz_0p05[0,:], pes_lz_0p05[1,:], 'b--', label='S0 lz = 0.05')
plt.legend()
plt.show()
