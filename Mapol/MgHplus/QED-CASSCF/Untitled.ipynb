# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
pes = np.load('mghplus_casscf_8e_12o_ccpVDZ_no_cavity.npy')

# %%
plt.plot(pes[0,:], pes[1,:])
plt.plot(pes[0,:], pes[2,:])
plt.plot(pes[0,:], pes[3,:])
